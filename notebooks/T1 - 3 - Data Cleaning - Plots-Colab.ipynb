# %% [markdown]
# <a href="https://colab.research.google.com/github/joanby/python-ml-course/blob/Collab---v-3.8/notebooks/T1%20-%203%20-%20Data%20Cleaning%20-%20Plots-Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Plots y visualización de los datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/halju/OneDrive/Documentos/GitHub/python-ml-course/datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
# %matplotlib inline

# %%
#savefig("path_donde_guardar_im.jpeg")

# %% [markdown]
# ### Scatter Plot

# %%
data.plot(kind="scatter", x="Day Mins", y="Day Charge")
plt.show()

# %%
x=data.plot(kind="scatter", x="Night Mins", y="Night Charge")
display(x.figure)

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
data.plot(kind="scatter", x="Day Mins", y ="Day Charge", ax=axs[0][0])
data.plot(kind="scatter", x="Night Mins", y="Night Charge", ax=axs[0][1])
data.plot(kind="scatter", x="Day Calls", y ="Day Charge", ax=axs[1][0])
data.plot(kind="scatter", x="Night Calls", y="Night Charge", ax=axs[1][1])
display(figure)

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
data.plot(kind="scatter", x="Day Mins", y ="Day Charge", ax=axs[0][0])
data.plot(kind="scatter", x="Night Mins", y="Night Charge", ax=axs[0][1])
data.plot(kind="scatter", x="Day Calls", y ="Day Charge", ax=axs[1][0])
data.plot(kind="scatter", x="Night Calls", y="Night Charge", ax=axs[1][1])
display(figure)

# %%
figure,axs=plt.subplots(2,2,sharex=True,sharey=True)
data.plot(kind='scatter',x='Day Mins',y='Day Charge',ax=axs[0][0])
display(figure)

# %% [markdown]
# ### Histogramas de frecuencias

# %%
fig, ax = plt.subplots()

# Bins cada 30 unidades desde 0 hasta 210
bins = np.arange(0, 210, 30)
ax.hist(data["Day Calls"], bins=20)

ax.set_xlabel("Número de llamadas al día")
ax.set_ylabel("Frecuencia")
ax.set_title("Histograma con bins personalizados")

display(fig)

# %% [markdown]
# ### Boxplot, diagrama de caja y bigotes

# %%
plt.boxplot(data["Day Calls"])
plt.ylabel("Número de llamadas diarias")
plt.title("Boxplot de las llamadas diarias")
# Out:
# Text(0.5, 1.0, 'Boxplot de las llamadas diarias')

# %%
data["Day Calls"].describe()
# Out:
# count    3333.000000
# mean      100.435644
# std        20.069084
# min         0.000000
# 25%        87.000000
# 50%       101.000000
# 75%       114.000000
# max       165.000000
# Name: Day Calls, dtype: float64

# %%
IQR=data["Day Calls"].quantile(0.75)-data["Day Calls"].quantile(0.25)
IQR
# Out:
# 27.0

# %%
data["Day Calls"].quantile(0.25) - 1.5*IQR
# Out:
# 46.5

# %%
data["Day Calls"].quantile(0.75) + 1.5*IQR
# Out:
# 154.5
